# %%
import pandas as pd

data = [[10, 200, 60], [12, 155, 45], [9, 50, -45], [16, 240, 90]]

df = pd.DataFrame(data, columns = ['Area' ,'Intensity' ,'Orientation'])
print(df)
# Out:
#    Area  Intensity  Orientation
# 0    10        200           60
# 1    12        155           45
# 2     9         50          -45
# 3    16        240           90

# %%
import pandas as pd;
df = pd.read_csv("./csv.csv", encoding= 'unicode_escape')
print(df.info())
print(df.head) #gives first 5 values
print(df.head(7))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 10 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   1                                                 99 non-null     int64
#  1   Eldon Base for stackable storage shelf, platinum  99 non-null     object
#  2   Muhammed MacIntyre                                99 non-null     object
#  3   3                                                 99 non-null     int64
#  4   -213.25                                           99 non-null     float64
#  5   38.94                                             99 non-null     float64
#  6   35                                                99 non-null     float64
#  7   Nunavut                                           99 non-null     object
#  8   Storage & Organization                            99 non-null     object
# ...

# %%
print(df.columns);
print(df.dtypes);
# Out:
# Index(['1', 'Eldon Base for stackable storage shelf, platinum',
#        'Muhammed MacIntyre', '3', '-213.25', '38.94', '35', 'Nunavut',
#        'Storage & Organization', '0.8'],
#       dtype='object')
# 1                                                     int64
# Eldon Base for stackable storage shelf, platinum     object
# Muhammed MacIntyre                                   object
# 3                                                     int64
# -213.25                                             float64
# 38.94                                               float64
# 35                                                  float64
# Nunavut                                              object
# Storage & Organization                               object
# 0.8                                                 float64
# dtype: object
